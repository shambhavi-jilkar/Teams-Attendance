# %%
# %pwd
# Out:
# 'C:\\Users\\Shambhavi\\Downloads\\Attendance (2021-22)\\Attendance (2021-22)'

# %%
div = ['6B','6C','6D','7B','7D']

# %% [markdown]
# ## 6B

# %%
import os
path = "C:\\Users\\Shambhavi\\Downloads\\Attendance (2021-22)\\Attendance (2021-22)\\6B French attendance (2021-22)\\August"

# %%
import pandas as  pd
import numpy as np
doc = pd.read_excel('VI B August Attendance.xlsx',
                   sheet_name='FRENCH',
                   skiprows=8)
doc['Student First Name'] = doc['Student First Name'].str.strip()
doc['Last Name'] = doc['Last Name'].str.strip()
doc['Full Name'] = doc['Student First Name'].map(str) + '.' + doc['Last Name'].map(str)
doc
# Out:
#     Roll No   GR No Student First Name   Last Name  1 Sun   2   3   4   5   6  \
# 0       1.0  4290.0               Saee  Ambasankar    NaN NaN NaN NaN NaN NaN
# 1       2.0     NaN             Anjali   Bhindwale    NaN NaN NaN NaN NaN NaN
# 2       3.0  4311.0            Sarthak     Badambe    NaN NaN NaN NaN NaN NaN
# 3       4.0  4272.0             Devika   Chaudhari    NaN NaN NaN NaN NaN NaN
# 4       5.0  4439.0              Anvay    Chougule    NaN NaN NaN NaN NaN NaN
# 5       6.0  4285.0              Aarya    Deshmukh    NaN NaN NaN NaN NaN NaN
# 6       7.0  4250.0               Yash      Dhotre    NaN NaN NaN NaN NaN NaN
# 7       8.0  4352.0             Chetak     Dongare    NaN NaN NaN NaN NaN NaN
# 8       9.0  4284.0             Shayan       Ghosh    NaN NaN NaN NaN NaN NaN
# 9      10.0  4310.0             Aarush       Goyal    NaN NaN NaN NaN NaN NaN
# 10     11.0  4345.0     Sesi Sai Ridhi     Gumpena    NaN NaN NaN NaN NaN NaN
# ...

# %%
doc.columns
# Out:
# Index([           'Roll No',              'GR No', 'Student First Name',
#                 'Last Name',              '1 Sun',                    2,
#                           3,                    4,                    5,
#                           6,              '7 Sat',              '8 Sun',
#                           9,                   10,                   11,
#                          12,                   13,             '14 Sat',
#                    '15 Sun',                   16,                   17,
#                          18,                   19,                   20,
#                    '21 Sat',             '22 Sun',                   23,
#                          24,                   25,                   26,
#                          27,             '28 Sat',             '29 Sun',
#                          30,                   31,          'Full Name'],
#       dtype='object')

# %%
# %cd "6B French attendance (2021-22)\\August"
# Out:
# C:\Users\Shambhavi\Downloads\Attendance (2021-22)\Attendance (2021-22)\6B French attendance (2021-22)\August

# %%
# %pwd
# Out:
# 'C:\\Users\\Shambhavi\\Downloads\\Attendance (2021-22)\\Attendance (2021-22)\\6B French attendance (2021-22)\\August'

# %%
for filename in os.listdir(path):    
    #print(filename)
    import re
    regex = re.compile("\d+$")
    day = [(x) for x in regex.findall(filename)]
    #print(day)
    if int(day[0]) in doc.columns:
        col = int(day[0])
    elif day[0]+' Sat' in doc.columns:
        col = day[0]+' Sat'
    f = open(filename, "r",encoding='utf-16')
    readfile = f.read()
    for i in doc['Full Name']:    
        if i in readfile:
            row = doc.index[doc['Full Name']==i]
            doc.at[row,col]='P'
            print(doc.loc[row,col])
        else:
            row = doc.index[doc['Full Name']==i]
            doc.at[row,col]='A'
            print(doc.loc[row,col])
# Out:
# 0    A
# Name: 10, dtype: object
# 1    A
# Name: 10, dtype: object
# 2    A
# Name: 10, dtype: object
# 3    A
# Name: 10, dtype: object
# 4    A
# Name: 10, dtype: object
# 5    A
# Name: 10, dtype: object
# 6    A
# Name: 10, dtype: object
# 7    A
# Name: 10, dtype: object
# 8    A
# Name: 10, dtype: object
# 9    A
# Name: 10, dtype: object
# 10    A
# Name: 10, dtype: object
# 11    A
# Name: 10, dtype: object
# 12    A
# Name: 10, dtype: object
# 13    A
# Name: 10, dtype: object
# 14    A
# Name: 10, dtype: object
# 15    A
# Name: 10, dtype: object
# 16    A
# Name: 10, dtype: object
# 17    A
# Name: 10, dtype: object
# 18    A
# Name: 10, dtype: object
# 19    A
# Name: 10, dtype: object
# 20    A
# Name: 10, dtype: object
# 21    A
# Name: 10, dtype: object
# 22    A
# Name: 10, dtype: object
# 23    A
# Name: 10, dtype: object
# 24    A
# Name: 10, dtype: object
# 25    A
# Name: 10, dtype: object
# 26    A
# Name: 10, dtype: object
# 27    A
# Name: 10, dtype: object
# ...

# %%
doc
# Out:
#     Roll No   GR No Student First Name   Last Name  1 Sun   2  3   4   5  6  \
# 0       1.0  4290.0               Saee  Ambasankar    NaN NaN  P NaN NaN  P
# 1       2.0     NaN             Anjali   Bhindwale    NaN NaN  A NaN NaN  A
# 2       3.0  4311.0            Sarthak     Badambe    NaN NaN  A NaN NaN  A
# 3       4.0  4272.0             Devika   Chaudhari    NaN NaN  P NaN NaN  P
# 4       5.0  4439.0              Anvay    Chougule    NaN NaN  A NaN NaN  A
# 5       6.0  4285.0              Aarya    Deshmukh    NaN NaN  P NaN NaN  P
# 6       7.0  4250.0               Yash      Dhotre    NaN NaN  A NaN NaN  A
# 7       8.0  4352.0             Chetak     Dongare    NaN NaN  A NaN NaN  A
# 8       9.0  4284.0             Shayan       Ghosh    NaN NaN  A NaN NaN  A
# 9      10.0  4310.0             Aarush       Goyal    NaN NaN  P NaN NaN  A
# 10     11.0  4345.0     Sesi Sai Ridhi     Gumpena    NaN NaN  A NaN NaN  A
# ...

# %%
doc.to_excel('6B August Attendance done.xlsx')

# %% [markdown]
# ## 6C

# %%
# %cd ..
# %cd ..
# Out:
# C:\Users\Shambhavi\Downloads\Attendance (2021-22)\Attendance (2021-22)\6B French attendance (2021-22)
# C:\Users\Shambhavi\Downloads\Attendance (2021-22)\Attendance (2021-22)

# %%
import os
path = "C:\\Users\\Shambhavi\\Downloads\\Attendance (2021-22)\\Attendance (2021-22)\\6C French attendance (2021-22)\\August"

# %%
import pandas as  pd
import numpy as np
doc = pd.read_excel('VI C August Attendance.xlsx',
                   sheet_name='French',
                   skiprows=8)
doc['Student First Name'] = doc['Student First Name'].str.strip()
doc['Last Name'] = doc['Last Name'].str.strip()
doc['Full Name'] = doc['Student First Name'].map(str) + '.' + doc['Last Name'].map(str)
doc
# Out:
#     Roll No  GR No Student First Name    Last Name  1 Sun   2   3   4   5   6  \
# 0         1   4354              Mohit        Bafna    NaN NaN NaN NaN NaN NaN
# 1         2   4243              Sejal       Baheti    NaN NaN NaN NaN NaN NaN
# 2         3   4593              Aarya       Bellad    NaN NaN NaN NaN NaN NaN
# 3         4   4287              Rashi        Bodke    NaN NaN NaN NaN NaN NaN
# 4         5   4367              Avani      Chaskar    NaN NaN NaN NaN NaN NaN
# 5         6   4304           Chhayank    Chaudhari    NaN NaN NaN NaN NaN NaN
# 6         7   4271             Shalvi    Deshpande    NaN NaN NaN NaN NaN NaN
# 7         8   4332            Shoanak    Deshpande    NaN NaN NaN NaN NaN NaN
# 8         9   4245             Naitik      Dhekane    NaN NaN NaN NaN NaN NaN
# 9        10   4251             Ishika       Dusane    NaN NaN NaN NaN NaN NaN
# 10       11   4279              Ayati      Ganjale    NaN NaN NaN NaN NaN NaN
# ...

# %%
doc.columns
# Out:
# Index([           'Roll No',              'GR No', 'Student First Name',
#                 'Last Name',              '1 Sun',                    2,
#                           3,                    4,                    5,
#                           6,              '7 Sat',              '8 Sun',
#                           9,                   10,                   11,
#                          12,                   13,             '14 Sat',
#                    '15 Sun',                   16,                   17,
#                          18,                   19,                   20,
#                    '21 Sat',             '22 Sun',                   23,
#                          24,                   25,                   26,
#                          27,             '28 Sat',             '29 Sun',
#                          30,                   31,          'Full Name'],
#       dtype='object')

# %%
# %cd "6C French attendance (2021-22)\\August"
# Out:
# C:\Users\Shambhavi\Downloads\Attendance (2021-22)\Attendance (2021-22)\6C French attendance (2021-22)\August

# %%
# %pwd
# Out:
# 'C:\\Users\\Shambhavi\\Downloads\\Attendance (2021-22)\\Attendance (2021-22)\\6C French attendance (2021-22)\\August'

# %%
for filename in os.listdir(path):    
    #print(filename)
    import re
    regex = re.compile("\d+$")
    day = [(x) for x in regex.findall(filename)]
    #print(day)
    if int(day[0]) in doc.columns:
        col = int(day[0])
    elif day[0]+' Sat' in doc.columns:
        col = day[0]+' Sat'
    f = open(filename, "r",encoding='utf-16')
    readfile = f.read()
    for i in doc['Full Name']:    
        if i in readfile:
            row = doc.index[doc['Full Name']==i]
            doc.at[row,col]='P'
            print(doc.loc[row,col])
        else:
            row = doc.index[doc['Full Name']==i]
            doc.at[row,col]='A'
            print(doc.loc[row,col])
# Out:
# 0    A
# Name: 11, dtype: object
# 1    P
# Name: 11, dtype: object
# 2    P
# Name: 11, dtype: object
# 3    P
# Name: 11, dtype: object
# 4    A
# Name: 11, dtype: object
# 5    A
# Name: 11, dtype: object
# 6    P
# Name: 11, dtype: object
# 7    A
# Name: 11, dtype: object
# 8    A
# Name: 11, dtype: object
# 9    P
# Name: 11, dtype: object
# 10    A
# Name: 11, dtype: object
# 11    P
# Name: 11, dtype: object
# 12    A
# Name: 11, dtype: object
# 13    P
# Name: 11, dtype: object
# 14    A
# Name: 11, dtype: object
# 15    P
# Name: 11, dtype: object
# 16    P
# Name: 11, dtype: object
# 17    P
# Name: 11, dtype: object
# 18    P
# Name: 11, dtype: object
# 19    P
# Name: 11, dtype: object
# 20    P
# Name: 11, dtype: object
# 21    A
# Name: 11, dtype: object
# 22    A
# Name: 11, dtype: object
# 23    A
# Name: 11, dtype: object
# 24    P
# Name: 11, dtype: object
# 25    P
# Name: 11, dtype: object
# 26    P
# Name: 11, dtype: object
# 27    A
# Name: 11, dtype: object
# ...

# %%
doc
# Out:
#     Roll No  GR No Student First Name    Last Name  1 Sun  2   3   4   5   6  \
# 0         1   4354              Mohit        Bafna    NaN  A NaN NaN NaN NaN
# 1         2   4243              Sejal       Baheti    NaN  P NaN NaN NaN NaN
# 2         3   4593              Aarya       Bellad    NaN  P NaN NaN NaN NaN
# 3         4   4287              Rashi        Bodke    NaN  P NaN NaN NaN NaN
# 4         5   4367              Avani      Chaskar    NaN  P NaN NaN NaN NaN
# 5         6   4304           Chhayank    Chaudhari    NaN  P NaN NaN NaN NaN
# 6         7   4271             Shalvi    Deshpande    NaN  P NaN NaN NaN NaN
# 7         8   4332            Shoanak    Deshpande    NaN  P NaN NaN NaN NaN
# 8         9   4245             Naitik      Dhekane    NaN  P NaN NaN NaN NaN
# 9        10   4251             Ishika       Dusane    NaN  P NaN NaN NaN NaN
# 10       11   4279              Ayati      Ganjale    NaN  P NaN NaN NaN NaN
# ...

# %%
doc.to_excel('6C August Attendance done.xlsx')

# %% [markdown]
# ## 6D

# %%
# %cd ..
# %cd ..
# Out:
# C:\Users\Shambhavi\Downloads\Attendance (2021-22)\Attendance (2021-22)\6C French attendance (2021-22)
# C:\Users\Shambhavi\Downloads\Attendance (2021-22)\Attendance (2021-22)

# %%
import os
path = "C:\\Users\\Shambhavi\\Downloads\\Attendance (2021-22)\\Attendance (2021-22)\\6D French attendance (2021-22)\\August"

# %%
import pandas as  pd
import numpy as np
doc = pd.read_excel('VI D August Attendance.xlsx',
                   sheet_name='French',
                   skiprows=8)
doc['Student First Name'] = doc['Student First Name'].str.strip()
doc['Last Name'] = doc['Last Name'].str.strip()
doc['Full Name'] = doc['Student First Name'].map(str) + '.' + doc['Last Name'].map(str)
doc
# Out:
#     Roll No  GR No Student First Name    Last Name  1 Sun   2   3   4   5   6  \
# 0         1   4307              Gyana        Anand    NaN NaN NaN NaN NaN NaN
# 1         2   4428              Arjun     Baviskar    NaN NaN NaN NaN NaN NaN
# 2         3   4355            Sharlet        Bonny    NaN NaN NaN NaN NaN NaN
# 3         4   4347              Arjun    Chaurasia    NaN NaN NaN NaN NaN NaN
# 4         5   4341             Suditi      Deepesh    NaN NaN NaN NaN NaN NaN
# 5         6   4258            Shalaka     Deshmukh    NaN NaN NaN NaN NaN NaN
# 6         7   4614              Rashi        Dugam    NaN NaN NaN NaN NaN NaN
# 7         8   4319              Arnav       Gosavi    NaN NaN NaN NaN NaN NaN
# 8         9   4340             Kaveri  Grampurohit    NaN NaN NaN NaN NaN NaN
# 9        10   4268             Saanvi        Gupta    NaN NaN NaN NaN NaN NaN
# 10       11   4293             Mardav         Jain    NaN NaN NaN NaN NaN NaN
# ...

# %%
doc.columns
# Out:
# Index([           'Roll No',              'GR No', 'Student First Name',
#                 'Last Name',              '1 Sun',                    2,
#                           3,                    4,                    5,
#                           6,              '7 Sat',              '8 Sun',
#                           9,                   10,                   11,
#                          12,                   13,             '14 Sat',
#                    '15 Sun',                   16,                   17,
#                          18,                   19,                   20,
#                    '21 Sat',             '22 Sun',                   23,
#                          24,                   25,                   26,
#                          27,             '28 Sat',             '29 Sun',
#                          30,                   31,          'Full Name'],
#       dtype='object')

# %%
# %cd "6D French attendance (2021-22)\\August"
# Out:
# C:\Users\Shambhavi\Downloads\Attendance (2021-22)\Attendance (2021-22)\6D French attendance (2021-22)\August

# %%
# %pwd
# Out:
# 'C:\\Users\\Shambhavi\\Downloads\\Attendance (2021-22)\\Attendance (2021-22)\\6D French attendance (2021-22)\\August'

# %%
for filename in os.listdir(path):    
    #print(filename)
    import re
    regex = re.compile("\d+$")
    day = [(x) for x in regex.findall(filename)]
    #print(day)
    if int(day[0]) in doc.columns:
        col = int(day[0])
    elif day[0]+' Sat' in doc.columns:
        col = day[0]+' Sat'
    f = open(filename, "r",encoding='utf-16')
    readfile = f.read()
    for i in doc['Full Name']:    
        if i in readfile:
            row = doc.index[doc['Full Name']==i]
            doc.at[row,col]='P'
            print(doc.loc[row,col])
        else:
            row = doc.index[doc['Full Name']==i]
            doc.at[row,col]='A'
            print(doc.loc[row,col])
# Out:
# 0    P
# Name: 13, dtype: object
# 1    A
# Name: 13, dtype: object
# 2    A
# Name: 13, dtype: object
# 3    A
# Name: 13, dtype: object
# 4    P
# Name: 13, dtype: object
# 5    P
# Name: 13, dtype: object
# 6    P
# Name: 13, dtype: object
# 7    A
# Name: 13, dtype: object
# 8    P
# Name: 13, dtype: object
# 9    A
# Name: 13, dtype: object
# 10    P
# Name: 13, dtype: object
# 11    P
# Name: 13, dtype: object
# 12    P
# Name: 13, dtype: object
# 13    P
# Name: 13, dtype: object
# 14    A
# Name: 13, dtype: object
# 15    A
# Name: 13, dtype: object
# 16    A
# Name: 13, dtype: object
# 17    P
# Name: 13, dtype: object
# 18    P
# Name: 13, dtype: object
# 19    A
# Name: 13, dtype: object
# 20    P
# Name: 13, dtype: object
# 21    P
# Name: 13, dtype: object
# 22    P
# Name: 13, dtype: object
# 23    A
# Name: 13, dtype: object
# 24    P
# Name: 13, dtype: object
# 25    A
# Name: 13, dtype: object
# 26    A
# Name: 13, dtype: object
# 27    P
# Name: 13, dtype: object
# ...

# %%
doc
# Out:
#     Roll No  GR No Student First Name    Last Name  1 Sun   2   3  4   5  6  \
# 0         1   4307              Gyana        Anand    NaN NaN NaN  A NaN  P
# 1         2   4428              Arjun     Baviskar    NaN NaN NaN  A NaN  A
# 2         3   4355            Sharlet        Bonny    NaN NaN NaN  A NaN  A
# 3         4   4347              Arjun    Chaurasia    NaN NaN NaN  A NaN  A
# 4         5   4341             Suditi      Deepesh    NaN NaN NaN  P NaN  P
# 5         6   4258            Shalaka     Deshmukh    NaN NaN NaN  P NaN  P
# 6         7   4614              Rashi        Dugam    NaN NaN NaN  P NaN  P
# 7         8   4319              Arnav       Gosavi    NaN NaN NaN  A NaN  A
# 8         9   4340             Kaveri  Grampurohit    NaN NaN NaN  P NaN  A
# 9        10   4268             Saanvi        Gupta    NaN NaN NaN  P NaN  P
# 10       11   4293             Mardav         Jain    NaN NaN NaN  P NaN  P
# ...

# %%
doc.to_excel('6D August Attendance done.xlsx')

# %% [markdown]
# ## 7B

# %%
# %cd ..
# %cd ..
# Out:
# C:\Users\Shambhavi\Downloads\Attendance (2021-22)\Attendance (2021-22)\7D French attendance (2021-22)
# C:\Users\Shambhavi\Downloads\Attendance (2021-22)\Attendance (2021-22)

# %%
import os
path = "C:\\Users\\Shambhavi\\Downloads\\Attendance (2021-22)\\Attendance (2021-22)\\7B French attendance (2021-22)\\August"

# %%
import pandas as  pd
import numpy as np
doc = pd.read_excel('VII B August Attendance.xlsx',
                   sheet_name='French',
                   skiprows=8)
doc['Student First Name'] = doc['Student First Name'].str.strip()
doc['Last Name'] = doc['Last Name'].str.strip()
doc['Full Name'] = doc['Student First Name'].map(str) + ' ' + doc['Last Name'].map(str)
doc
# Out:
#     Roll No   GR No Student First Name      Last Name  1 Sun   2   3   4   5  \
# 0       2.0  3985.0            Aaditya        Akolkar    NaN NaN NaN NaN NaN
# 1       6.0  4100.0              Preet  Daulatabadkar    NaN NaN NaN NaN NaN
# 2      10.0  4939.0            Dishita      Dharmawat    NaN NaN NaN NaN NaN
# 3      11.0  4121.0              Vibhi         Duggal    NaN NaN NaN NaN NaN
# 4      13.0  5552.0              Aadya         Ghumre    NaN NaN NaN NaN NaN
# 5      16.0  3991.0             Khyati           Jain    NaN NaN NaN NaN NaN
# 6      17.0  3990.0             Aahana           Kale    NaN NaN NaN NaN NaN
# 7      18.0  3993.0                Ira          Khade    NaN NaN NaN NaN NaN
# 8      19.0  4027.0              Netra    Malkarnekar    NaN NaN NaN NaN NaN
# 9      21.0  4055.0             Riddhi          Misal    NaN NaN NaN NaN NaN
# 10     25.0  5604.0            Anannya      Kolwankar    NaN NaN NaN NaN NaN
# ...

# %%
doc.columns
# Out:
# Index([           'Roll No',              'GR No', 'Student First Name',
#                 'Last Name',              '1 Sun',                    2,
#                           3,                    4,                    5,
#                           6,              '7 Sat',              '8 Sun',
#                           9,                   10,                   11,
#                          12,                   13,             '14 Sat',
#                    '15 Sun',                   16,                   17,
#                          18,                   19,                   20,
#                    '21 Sat',             '22 Sun',                   23,
#                          24,                   25,                   26,
#                          27,             '28 Sat',             '29 Sun',
#                          30,                   31,          'Full Name'],
#       dtype='object')

# %%
# %cd "7B French attendance (2021-22)\\August"
# Out:
# C:\Users\Shambhavi\Downloads\Attendance (2021-22)\Attendance (2021-22)\7B French attendance (2021-22)\August

# %%
# %pwd
# Out:
# 'C:\\Users\\Shambhavi\\Downloads\\Attendance (2021-22)\\Attendance (2021-22)\\7B French attendance (2021-22)\\August'

# %%
for filename in os.listdir(path):    
    #print(filename)
    import re
    regex = re.compile("\d+$")
    day = [(x) for x in regex.findall(filename)]
    #print(day)
    if int(day[0]) in doc.columns:
        col = int(day[0])
    elif day[0]+' Sat' in doc.columns:
        col = day[0]+' Sat'
    f = open(filename, "r",encoding='utf-16')
    readfile = f.read()
    for i in doc['Full Name']:    
        if i in readfile:
            row = doc.index[doc['Full Name']==i]
            doc.at[row,col]='P'
            print(doc.loc[row,col])
        else:
            row = doc.index[doc['Full Name']==i]
            doc.at[row,col]='A'
            print(doc.loc[row,col])
# Out:
# 0    A
# Name: 13, dtype: object
# 1    P
# Name: 13, dtype: object
# 2    P
# Name: 13, dtype: object
# 3    P
# Name: 13, dtype: object
# 4    A
# Name: 13, dtype: object
# 5    A
# Name: 13, dtype: object
# 6    A
# Name: 13, dtype: object
# 7    A
# Name: 13, dtype: object
# 8    A
# Name: 13, dtype: object
# 9    P
# Name: 13, dtype: object
# 10    A
# Name: 13, dtype: object
# 11    P
# Name: 13, dtype: object
# 12    A
# Name: 13, dtype: object
# 13    A
# Name: 13, dtype: object
# 14    A
# Name: 13, dtype: object
# 15    A
# Name: 13, dtype: object
# 16    A
# Name: 13, dtype: object
# 17    A
# Name: 13, dtype: object
# 18    A
# Name: 13, dtype: object
# 19    A
# Name: 13, dtype: object
# 0    P
# Name: 12, dtype: object
# 1    P
# Name: 12, dtype: object
# 2    P
# Name: 12, dtype: object
# 3    P
# Name: 12, dtype: object
# 4    A
# Name: 12, dtype: object
# 5    A
# Name: 12, dtype: object
# 6    P
# Name: 12, dtype: object
# 7    A
# Name: 12, dtype: object
# 8    A
# ...

# %%
doc
# Out:
#     Roll No   GR No Student First Name      Last Name  1 Sun   2   3   4  5  \
# 0       2.0  3985.0            Aaditya        Akolkar    NaN NaN NaN NaN  A
# 1       6.0  4100.0              Preet  Daulatabadkar    NaN NaN NaN NaN  A
# 2      10.0  4939.0            Dishita      Dharmawat    NaN NaN NaN NaN  A
# 3      11.0  4121.0              Vibhi         Duggal    NaN NaN NaN NaN  A
# 4      13.0  5552.0              Aadya         Ghumre    NaN NaN NaN NaN  A
# 5      16.0  3991.0             Khyati           Jain    NaN NaN NaN NaN  A
# 6      17.0  3990.0             Aahana           Kale    NaN NaN NaN NaN  A
# 7      18.0  3993.0                Ira          Khade    NaN NaN NaN NaN  A
# 8      19.0  4027.0              Netra    Malkarnekar    NaN NaN NaN NaN  A
# 9      21.0  4055.0             Riddhi          Misal    NaN NaN NaN NaN  A
# 10     25.0  5604.0            Anannya      Kolwankar    NaN NaN NaN NaN  A
# ...

# %%
doc.to_excel('7B August Attendance done.xlsx')

# %% [markdown]
# ## 7D

# %%
# %cd ..
# %cd ..
# Out:
# C:\Users\Shambhavi\Downloads\Attendance (2021-22)\Attendance (2021-22)\7D French attendance (2021-22)
# C:\Users\Shambhavi\Downloads\Attendance (2021-22)\Attendance (2021-22)

# %%
import os
path = "C:\\Users\\Shambhavi\\Downloads\\Attendance (2021-22)\\Attendance (2021-22)\\7D French attendance (2021-22)\\August"

# %%
import pandas as  pd
import numpy as np
doc = pd.read_excel('VII D August Attendance.xlsx',
                   sheet_name='French',
                   skiprows=8)
doc['Student First Name'] = doc['Student First Name'].str.strip()
doc['Last Name'] = doc['Last Name'].str.strip()
doc['Full Name'] = doc['Student First Name'].map(str) + ' ' + doc['Last Name'].map(str)
doc
# Out:
#     Roll No   GR No Student First Name             Last Name  1 Sun   2   3  \
# 0       1.0  4090.0            Aarushi               Agarwal    NaN NaN NaN
# 1       2.0  4013.0              Deven                 Albal    NaN NaN NaN
# 2       3.0  4085.0               Arya                 Borde    NaN NaN NaN
# 3       4.0  3997.0             Akshay            Borgaonkar    NaN NaN NaN
# 4       5.0  4127.0            Shailee                 Dalvi    NaN NaN NaN
# 5       6.0  4083.0             Adveit             Deshpande    NaN NaN NaN
# 6       7.0  4130.0             Sakshi                Dharma    NaN NaN NaN
# 7       8.0  4081.0             Aarush              Dhaygude    NaN NaN NaN
# 8       9.0  4079.0             Arisha              Gangrade    NaN NaN NaN
# 9      10.0  4012.0             Armaan                 Hazra    NaN NaN NaN
# 10     11.0  4924.0              Purva                  Hole    NaN NaN NaN
# ...

# %%
doc.columns
# Out:
# Index([           'Roll No',              'GR No', 'Student First Name',
#                 'Last Name',              '1 Sun',                    2,
#                           3,                    4,                    5,
#                           6,              '7 Sat',              '8 Sun',
#                           9,                   10,                   11,
#                          12,                   13,             '14 Sat',
#                    '15 Sun',                   16,                   17,
#                          18,                   19,                   20,
#                    '21 Sat',             '22 Sun',                   23,
#                          24,                   25,                   26,
#                          27,             '28 Sat',             '29 Sun',
#                          30,                   31,          'Full Name'],
#       dtype='object')

# %%
# %cd "7D French attendance (2021-22)\\August"
# Out:
# C:\Users\Shambhavi\Downloads\Attendance (2021-22)\Attendance (2021-22)\7D French attendance (2021-22)\August

# %%
# %pwd
# Out:
# 'C:\\Users\\Shambhavi\\Downloads\\Attendance (2021-22)\\Attendance (2021-22)\\7D French attendance (2021-22)\\August'

# %%
for filename in os.listdir(path):    
    #print(filename)
    import re
    regex = re.compile("\d+$")
    day = [(x) for x in regex.findall(filename)]
    #print(day)
    if int(day[0]) in doc.columns:
        col = int(day[0])
    elif day[0]+' Sat' in doc.columns:
        col = day[0]+' Sat'
    f = open(filename, "r",encoding='utf-16')
    readfile = f.read()
    for i in doc['Full Name']:    
        if i in readfile:
            row = doc.index[doc['Full Name']==i]
            doc.at[row,col]='P'
            print(doc.loc[row,col])
        else:
            row = doc.index[doc['Full Name']==i]
            doc.at[row,col]='A'
            print(doc.loc[row,col])
# Out:
# 0    A
# Name: 10, dtype: object
# 1    P
# Name: 10, dtype: object
# 2    A
# Name: 10, dtype: object
# 3    A
# Name: 10, dtype: object
# 4    A
# Name: 10, dtype: object
# 5    A
# Name: 10, dtype: object
# 6    P
# Name: 10, dtype: object
# 7    A
# Name: 10, dtype: object
# 8    P
# Name: 10, dtype: object
# 9    A
# Name: 10, dtype: object
# 10    A
# Name: 10, dtype: object
# 11    P
# Name: 10, dtype: object
# 12    P
# Name: 10, dtype: object
# 13    P
# Name: 10, dtype: object
# 14    A
# Name: 10, dtype: object
# 15    P
# Name: 10, dtype: object
# 16    A
# Name: 10, dtype: object
# 17    P
# Name: 10, dtype: object
# 18    P
# Name: 10, dtype: object
# 19    A
# Name: 10, dtype: object
# 20    P
# Name: 10, dtype: object
# 21    A
# Name: 10, dtype: object
# 22    A
# Name: 10, dtype: object
# 23    P
# Name: 10, dtype: object
# 24    A
# Name: 10, dtype: object
# 25    A
# Name: 10, dtype: object
# 26    A
# Name: 10, dtype: object
# 27    A
# Name: 10, dtype: object
# ...

# %%
doc
# Out:
#     Roll No   GR No Student First Name             Last Name  1 Sun   2  3  \
# 0       1.0  4090.0            Aarushi               Agarwal    NaN NaN  A
# 1       2.0  4013.0              Deven                 Albal    NaN NaN  P
# 2       3.0  4085.0               Arya                 Borde    NaN NaN  P
# 3       4.0  3997.0             Akshay            Borgaonkar    NaN NaN  A
# 4       5.0  4127.0            Shailee                 Dalvi    NaN NaN  A
# 5       6.0  4083.0             Adveit             Deshpande    NaN NaN  P
# 6       7.0  4130.0             Sakshi                Dharma    NaN NaN  A
# 7       8.0  4081.0             Aarush              Dhaygude    NaN NaN  A
# 8       9.0  4079.0             Arisha              Gangrade    NaN NaN  P
# 9      10.0  4012.0             Armaan                 Hazra    NaN NaN  A
# 10     11.0  4924.0              Purva                  Hole    NaN NaN  A
# ...

# %%
doc.to_excel('7D August Attendance done.xlsx')
